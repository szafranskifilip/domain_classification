# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ## Load Data

# %%
df_benign = pd.read_csv('Data/CSV_benign.csv')
df_malware = pd.read_csv('Data/CSV_malware.csv')
# Out:
# /var/folders/l2/k0kzp4_94t124f1tz8_9bd9r0000gn/T/ipykernel_30079/956180555.py:1: DtypeWarning: Columns (9,10,12,13,17,18,20,21,24,25,27,28,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_benign = pd.read_csv('Data/CSV_benign.csv')

# %%
# Label data
df_benign['label'] = 0
df_malware['label'] = 1

# %% [markdown]
# Check if both csv files have the same features

# %%
#Check if the two dataset have the same columns
sorted(list(df_malware.columns)) == sorted(list(df_benign.columns))
# Out:
# True

# %% [markdown]
# Check for duplicates

# %%
len(df_benign[df_benign.duplicated()])
# Out:
# 15522

# %%
len(df_malware[df_malware.duplicated()])
# Out:
# 22

# %%
#Remove duplicates
df_benign = df_benign.drop_duplicates()
df_malware = df_malware.drop_duplicates()

# %%
print(len(df_benign))
print(len(df_malware))
# Out:
# 478613
# 4977

# %%
#Concatenate datasets
df = pd.concat([df_benign, df_malware])
df_concat = df

# %%
df_concat
# Out:
#      Country       ASN    TTL               IP  \
# 0         US   15169.0     46    172.217.1.174
# 1        NaN       NaN    299              NaN
# 2        NaN       NaN     38              NaN
# 3         US   15169.0    299  172.217.164.228
# 4        NaN       NaN     96              NaN
# ...      ...       ...    ...              ...
# 4994      DE   24940.0  14399   148.251.70.130
# 4995      NL  204915.0   3599    145.14.145.85
# 4996     NaN       NaN   3599              NaN
# 4997      DE    8767.0   1799    62.245.182.18
# 4998      DE    8767.0   1799    62.245.182.48
#
#                                         Domain    State Registrant_Name  \
# 0                               b'google.com.'       CA             NaN
# 1                               b'google.com.'       CA             NaN
# 2                           b'www.google.com.'      NaN             NaN
# 3                           b'www.google.com.'      NaN             NaN
# 4                             b'facebook.com.'       CA             NaN
# ...                                        ...      ...             ...
# 4994                  b'naveenmechanical.com.'      NaN             NaN
# 4995  b'onlinefrepdfviewer.000webhostapp.com.'  Larnaka             NaN
# 4996  b'onlinefrepdfviewer.000webhostapp.com.'  Larnaka             NaN
# 4997                  b'stefanie-bolemant.de.'      NaN             NaN
# 4998                        b'web.asamnet.de.'      NaN             NaN
#
#      Country.1   Creation_Date_Time hex_32  ...  \
# 0           US  1997-09-15 04:00:00      0  ...
# 1           US  1997-09-15 04:00:00      0  ...
# 2          NaN  1997-09-15 04:00:00      0  ...
# 3          NaN                  NaN      0  ...
# 4           US  1997-03-29 05:00:00      0  ...
# ...        ...                  ...    ...  ...
# 4994       NaN                  NaN      0  ...
# 4995        CY  2016-05-11 13:34:12      0  ...
# 4996        CY  2016-05-11 13:34:12      0  ...
# 4997       NaN                  NaN      0  ...
# 4998       NaN                  NaN      0  ...
#
#                                                  typos oc_8  \
# 0         [('google.com', 100), ('google.com.br', 95)]    0
# 1         [('google.com', 100), ('google.com.br', 95)]    0
# 2         [('google.com', 100), ('google.com.br', 95)]    0
# 3         [('google.com', 100), ('google.com.br', 95)]    0
# 4              [('facebook.com', 100), ('qq.com', 86)]    0
# ...                                                ...  ...
# 4994       [('facebook.com', 86), ('twitter.com', 86)]    0
# 4995         [('twitter.com', 86), ('google.com', 86)]    0
# 4996         [('twitter.com', 86), ('google.com', 86)]    0
# 4997         [('google.de', 86), ('e-recht24.de', 86)]    0
# 4998  [('gesetze-im-internet.de', 86), ('web.de', 86)]    0
#
#                                                   3gram  \
# 0                          ['goo', 'oog', 'ogl', 'gle']
# 1                          ['goo', 'oog', 'ogl', 'gle']
# 2                          ['goo', 'oog', 'ogl', 'gle']
# 3                          ['goo', 'oog', 'ogl', 'gle']
# 4            ['fac', 'ace', 'ceb', 'ebo', 'boo', 'ook']
# ...                                                 ...
# 4994  ['nav', 'ave', 'vee', 'een', 'enm', 'nme', 'me...
# 4995  ['000', '00w', '0we', 'web', 'ebh', 'bho', 'ho...
# 4996  ['000', '00w', '0we', 'web', 'ebh', 'bho', 'ho...
# 4997  ['ste', 'tef', 'efa', 'fan', 'ani', 'nie', 'ie...
# 4998                ['asa', 'sam', 'amn', 'mne', 'net']
#
#                                       char_distribution  \
# 0     defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'g...
# 1     defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'g...
# 2     defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'w...
# 3     defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'w...
# 4     defaultdict(<class 'int'>, {'e': 1, 'c': 1, 'o...
# ...                                                 ...
# 4994  defaultdict(<class 'int'>, {'v': 1, 'n': 3, 'e...
# 4995  defaultdict(<class 'int'>, {'d': 1, 'n': 2, 'r...
# 4996  defaultdict(<class 'int'>, {'d': 1, 'n': 2, 'r...
# 4997  defaultdict(<class 'int'>, {'-': 1, 'n': 2, 'm...
# 4998  defaultdict(<class 'int'>, {'t': 1, 'n': 1, 'a...
#
#                                                   2gram          Registrar  \
# 0                        ['go', 'oo', 'og', 'gl', 'le']   MarkMonitor inc.
# 1                        ['go', 'oo', 'og', 'gl', 'le']   MarkMonitor inc.
# 2                        ['go', 'oo', 'og', 'gl', 'le']   MarkMonitor Inc.
# 3                        ['go', 'oo', 'og', 'gl', 'le']                NaN
# 4            ['fa', 'ac', 'ce', 'eb', 'bo', 'oo', 'ok']  RegistrarSafe LLC
# ...                                                 ...                ...
# 4994  ['na', 'av', 've', 'ee', 'en', 'nm', 'me', 'ec...                NaN
# 4995  ['00', '00', '0w', 'we', 'eb', 'bh', 'ho', 'os...      Hostinger UAB
# 4996  ['00', '00', '0w', 'we', 'eb', 'bh', 'ho', 'os...      Hostinger UAB
# 4997  ['st', 'te', 'ef', 'fa', 'an', 'ni', 'ie', 'e-...                NaN
# 4998               ['as', 'sa', 'am', 'mn', 'ne', 'et']                NaN
#
#                     sld Name_Server_Count Page_Rank label
# 0                google               8.0      -1.0     0
# 1                google               8.0      -1.0     0
# 2                google               4.0      -1.0     0
# 3                google               NaN       NaN     0
# 4              facebook               4.0      -1.0     0
# ...                 ...               ...       ...   ...
# 4994   naveenmechanical               NaN       NaN     1
# 4995      000webhostapp               4.0      -1.0     1
# 4996      000webhostapp               4.0      -1.0     1
# 4997  stefanie-bolemant               0.0      -1.0     1
# 4998            asamnet               0.0      -1.0     1
#
# [483590 rows x 39 columns]

# %% [markdown]
# Class Imbalance

# %%
labels = df_concat['label'].value_counts()
labels
# Out:
# label
# 0    478613
# 1      4977
# Name: count, dtype: int64

# %%
# Create a bar plot
plt.figure(figsize=(10, 6))
labels.plot(kind='bar', color='skyblue')
plt.title('Class Imbalance')
plt.xlabel('Label')
plt.ylabel('Count')
plt.xticks(rotation=0)  # Rotate x-axis labels for readability
plt.show()

# %% [markdown]
# ## EDA

# %%
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 483590 entries, 0 to 4998
# Data columns (total 39 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Country             377980 non-null  object
#  1   ASN                 378035 non-null  float64
#  2   TTL                 483590 non-null  object
#  3   IP                  379255 non-null  object
#  4   Domain              483590 non-null  object
#  5   State               220137 non-null  object
#  6   Registrant_Name     13238 non-null   object
#  7   Country.1           256116 non-null  object
#  8   Creation_Date_Time  365670 non-null  object
#  9   hex_32              483479 non-null  object
#  10  hex_8               483590 non-null  object
#  11  Domain_Name         396583 non-null  object
#  12  Alexa_Rank          435204 non-null  object
#  13  subdomain           483574 non-null  object
#  14  Organization        203860 non-null  object
#  15  len                 483244 non-null  object
#  16  longest_word        483461 non-null  object
#  17  oc_32               483587 non-null  object
#  18  shortened           482279 non-null  object
#  19  1gram               483568 non-null  object
#  20  obfuscate_at_sign   483590 non-null  object
#  21  entropy             483586 non-null  object
#  22  Domain_Age          435208 non-null  object
#  23  tld                 483587 non-null  object
#  24  dec_8               483580 non-null  object
#  25  dec_32              483496 non-null  object
#  26  Emails              325086 non-null  object
#  27  numeric_percentage  482813 non-null  object
#  28  puny_coded          483590 non-null  object
#  29  typos               483590 non-null  object
#  30  oc_8                483590 non-null  object
#  31  3gram               483590 non-null  object
#  32  char_distribution   483590 non-null  object
#  33  2gram               483415 non-null  object
#  34  Registrar           356625 non-null  object
#  35  sld                 482264 non-null  object
#  36  Name_Server_Count   435168 non-null  object
#  37  Page_Rank           434720 non-null  float64
#  38  label               483590 non-null  int64
# dtypes: float64(2), int64(1), object(36)
# memory usage: 147.6+ MB

# %%
# Data summarization function
def data_summary(data, ascending=False):
    
    summary = pd.DataFrame(data.isna().sum(), columns=['nan_count'])

    unique_val = []
    types_val = []
    zero_val = []

    for column in data.columns:
        unique = len(data[column].unique())
        types = str(data[column].dtype)
        zeros = len(data[data[column]==0])

        unique_val.append(unique)
        types_val.append(types)
        zero_val.append(zeros)

    summary['nan_percentage'] = round((data.isnull().sum() / len(data)) * 100, 1)
    summary['Unique_val count'] = unique_val
    summary['unique_percentage'] = round((data.nunique() / len(data)) * 100, 1)
    summary['Zero values count'] = zero_val
    summary['Data type'] = types_val

    summary.sort_values(by=['nan_count', 'Zero values count'], ascending=ascending)
    
    return summary

# %%
# Create summary of Nan and unique values counts and data types
data_summary(df_concat)
# Out:
#                     nan_count  nan_percentage  Unique_val count  \
# Country                105610            21.8               285
# ASN                    105555            21.8             10357
# TTL                         0             0.0             12864
# IP                     104335            21.6            177855
# Domain                      0             0.0            313538
# State                  263453            54.5              5814
# Registrant_Name        470352            97.3              4203
# Country.1              227474            47.0              1620
# Creation_Date_Time     117920            24.4            145659
# hex_32                    111             0.0               124
# hex_8                       0             0.0                20
# Domain_Name             87007            18.0            195952
# Alexa_Rank              48386            10.0            115298
# subdomain                  16             0.0               184
# Organization           279730            57.8             39735
# len                       346             0.1               515
# longest_word              129             0.0             34204
# oc_32                       3             0.0              7205
# shortened                1311             0.3                98
# 1gram                      22             0.0            211753
# obfuscate_at_sign           0             0.0             13505
# entropy                     4             0.0              4658
# Domain_Age              48382            10.0            333589
# tld                         3             0.0             31786
# dec_8                      10             0.0                77
# dec_32                     94             0.0               164
# Emails                 158504            32.8             44745
# numeric_percentage        777             0.2              9959
# puny_coded                  0             0.0               190
# typos                       0             0.0             30268
# oc_8                        0             0.0               926
# 3gram                       0             0.0            210746
# char_distribution           0             0.0            284881
# 2gram                     175             0.0            229924
# Registrar              126965            26.3             17290
# sld                      1326             0.3            177014
# Name_Server_Count       48422            10.0             50781
# Page_Rank               48870            10.1                31
# label                       0             0.0                 2
#
#                     unique_percentage  Zero values count Data type
# Country                           0.1                  0    object
# ASN                               2.1                  0   float64
# TTL                               2.7                738    object
# IP                               36.8                  0    object
# Domain                           64.8                  0    object
# State                             1.2                  0    object
# Registrant_Name                   0.9                  0    object
# Country.1                         0.3                  0    object
# Creation_Date_Time               30.1                  0    object
# hex_32                            0.0              20517    object
# hex_8                             0.0             213336    object
# Domain_Name                      40.5                  0    object
# Alexa_Rank                       23.8                  0    object
# subdomain                         0.0              15953    object
# Organization                      8.2                  0    object
# len                               0.1                  0    object
# longest_word                      7.1                  0    object
# oc_32                             1.5              20504    object
# shortened                         0.0               1388    object
# 1gram                            43.8                  0    object
# obfuscate_at_sign                 2.8              20505    object
# entropy                           1.0               1395    object
# Domain_Age                       69.0                  0    object
# tld                               6.6                  0    object
# dec_8                             0.0              20517    object
# dec_32                            0.0               7453    object
# Emails                            9.3                  0    object
# numeric_percentage                2.1              18831    object
# puny_coded                        0.0               7495    object
# typos                             6.3                  0    object
# oc_8                              0.2               4977    object
# 3gram                            43.6                  0    object
# char_distribution                58.9                  0    object
# 2gram                            47.5                  0    object
# Registrar                         3.6                  0    object
# sld                              36.6                  0    object
# Name_Server_Count                10.5               3400    object
# Page_Rank                         0.0               1383   float64
# label                             0.0             478613     int64

# %%
# Calculate the percentage of NaN values in each column
nan_percentage = (df_concat.isnull().sum() / len(df_concat)) * 100

# %%
# Create a bar plot
plt.figure(figsize=(10, 6))
nan_percentage.plot(kind='bar', color='skyblue')
plt.title('Percentage of NaN Values in Each Column')
plt.xlabel('Columns')
plt.ylabel('Percentage (%)')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.show()

# %% [markdown]
# ## Data Cleaning

# %%
df_concat.head(3).T
# Out:
#                                                                     0  \
# Country                                                            US
# ASN                                                           15169.0
# TTL                                                                46
# IP                                                      172.217.1.174
# Domain                                                 b'google.com.'
# State                                                              CA
# Registrant_Name                                                   NaN
# Country.1                                                          US
# Creation_Date_Time                                1997-09-15 04:00:00
# hex_32                                                              0
# hex_8                                                               0
# Domain_Name                              ['GOOGLE.COM', 'google.com']
# Alexa_Rank                                                        1.0
# subdomain                                                           0
# Organization                                               Google LLC
# len                                                                 7
# longest_word                                                   google
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                                  ['g', 'o', 'o', 'g', 'l', 'e']
# obfuscate_at_sign                                                 0.0
# entropy                                            1.8348756474779464
# Domain_Age                                  8256 days 11:53:49.631067
# tld                                                               com
# dec_8                                                               0
# dec_32                                                              0
# Emails              ['abusecomplaints@markmonitor.com', 'whoisrequ...
# numeric_percentage                                                0.0
# puny_coded                                                          0
# typos                    [('google.com', 100), ('google.com.br', 95)]
# oc_8                                                                0
# 3gram                                    ['goo', 'oog', 'ogl', 'gle']
# char_distribution   defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'g...
# 2gram                                  ['go', 'oo', 'og', 'gl', 'le']
# Registrar                                            MarkMonitor inc.
# sld                                                            google
# Name_Server_Count                                                 8.0
# Page_Rank                                                        -1.0
# label                                                               0
#
#                                                                     1  \
# Country                                                           NaN
# ASN                                                               NaN
# TTL                                                               299
# IP                                                                NaN
# Domain                                                 b'google.com.'
# State                                                              CA
# Registrant_Name                                                   NaN
# Country.1                                                          US
# Creation_Date_Time                                1997-09-15 04:00:00
# hex_32                                                              0
# hex_8                                                               0
# Domain_Name                              ['GOOGLE.COM', 'google.com']
# Alexa_Rank                                                        1.0
# subdomain                                                           0
# Organization                                               Google LLC
# len                                                                 7
# longest_word                                                   google
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                                  ['g', 'o', 'o', 'g', 'l', 'e']
# obfuscate_at_sign                                                 0.0
# entropy                                            1.8348756474779464
# Domain_Age                                  8256 days 11:53:50.479085
# tld                                                               com
# dec_8                                                               0
# dec_32                                                              0
# Emails              ['abusecomplaints@markmonitor.com', 'whoisrequ...
# numeric_percentage                                                0.0
# puny_coded                                                          0
# typos                    [('google.com', 100), ('google.com.br', 95)]
# oc_8                                                                0
# 3gram                                    ['goo', 'oog', 'ogl', 'gle']
# char_distribution   defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'g...
# 2gram                                  ['go', 'oo', 'og', 'gl', 'le']
# Registrar                                            MarkMonitor inc.
# sld                                                            google
# Name_Server_Count                                                 8.0
# Page_Rank                                                        -1.0
# label                                                               0
#
#                                                                     2
# Country                                                           NaN
# ASN                                                               NaN
# TTL                                                                38
# IP                                                                NaN
# Domain                                             b'www.google.com.'
# State                                                             NaN
# Registrant_Name                                                   NaN
# Country.1                                                         NaN
# Creation_Date_Time                                1997-09-15 04:00:00
# hex_32                                                              0
# hex_8                                                               0
# Domain_Name                                                GOOGLE.COM
# Alexa_Rank                                                        1.0
# subdomain                                                           1
# Organization                                                      NaN
# len                                                                10
# longest_word                                                   google
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                                  ['g', 'o', 'o', 'g', 'l', 'e']
# obfuscate_at_sign                                                 0.0
# entropy                                            2.1142465351822795
# Domain_Age                                  8256 days 11:53:51.264191
# tld                                                               com
# dec_8                                                               0
# dec_32                                                              0
# Emails                                abusecomplaints@markmonitor.com
# numeric_percentage                                                0.0
# puny_coded                                                          0
# typos                    [('google.com', 100), ('google.com.br', 95)]
# oc_8                                                                0
# 3gram                                    ['goo', 'oog', 'ogl', 'gle']
# char_distribution   defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'w...
# 2gram                                  ['go', 'oo', 'og', 'gl', 'le']
# Registrar                                            MarkMonitor Inc.
# sld                                                            google
# Name_Server_Count                                                 4.0
# Page_Rank                                                        -1.0
# label                                                               0

# %%
# Drop columns with high number of nan values
# Set the threshold for missing data (75%)
threshold = 0.25 * len(df_concat)

# Drop columns with missing data exceeding the threshold
df_concat = df_concat.dropna(thresh=threshold, axis=1)

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Convert 'Creation_Date_Time' to a proper date format. The errors parameter can be set to 'coerce,' 
# which forces any parsing errors to be set as NaT (Not a Timestamp).
df_concat['Creation_Date_Time'] = pd.to_datetime(df_concat['Creation_Date_Time'], errors='coerce')

# %%
#Split 'Creation_Date_Time' into seperate year and month columns
# Create 'Year' and 'Month' columns
df_concat['Year'] = df_concat['Creation_Date_Time'].dt.year
df_concat['Month'] = df_concat['Creation_Date_Time'].dt.month

# %%
# Use regex to extract the number of days from Domain_Age column
df_concat['Domain_Age'] = df_concat['Domain_Age'].str.extract(r'(\d+) days').astype(float)

# %%
# Drop datetime column
df_concat = df_concat.drop(columns=['Creation_Date_Time'])

# %%
df_concat.head(3).T
# Out:
#                                                                     0  \
# Country                                                            US
# ASN                                                           15169.0
# TTL                                                                46
# IP                                                      172.217.1.174
# Domain                                                 b'google.com.'
# State                                                              CA
# Country.1                                                          US
# hex_32                                                              0
# hex_8                                                               0
# Domain_Name                              ['GOOGLE.COM', 'google.com']
# Alexa_Rank                                                        1.0
# subdomain                                                           0
# Organization                                               Google LLC
# len                                                                 7
# longest_word                                                   google
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                                  ['g', 'o', 'o', 'g', 'l', 'e']
# obfuscate_at_sign                                                 0.0
# entropy                                            1.8348756474779464
# Domain_Age                                                     8256.0
# tld                                                               com
# dec_8                                                               0
# dec_32                                                              0
# Emails              ['abusecomplaints@markmonitor.com', 'whoisrequ...
# numeric_percentage                                                0.0
# puny_coded                                                          0
# typos                    [('google.com', 100), ('google.com.br', 95)]
# oc_8                                                                0
# 3gram                                    ['goo', 'oog', 'ogl', 'gle']
# char_distribution   defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'g...
# 2gram                                  ['go', 'oo', 'og', 'gl', 'le']
# Registrar                                            MarkMonitor inc.
# sld                                                            google
# Name_Server_Count                                                 8.0
# Page_Rank                                                        -1.0
# label                                                               0
# Year                                                           1997.0
# Month                                                             9.0
#
#                                                                     1  \
# Country                                                           NaN
# ASN                                                               NaN
# TTL                                                               299
# IP                                                                NaN
# Domain                                                 b'google.com.'
# State                                                              CA
# Country.1                                                          US
# hex_32                                                              0
# hex_8                                                               0
# Domain_Name                              ['GOOGLE.COM', 'google.com']
# Alexa_Rank                                                        1.0
# subdomain                                                           0
# Organization                                               Google LLC
# len                                                                 7
# longest_word                                                   google
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                                  ['g', 'o', 'o', 'g', 'l', 'e']
# obfuscate_at_sign                                                 0.0
# entropy                                            1.8348756474779464
# Domain_Age                                                     8256.0
# tld                                                               com
# dec_8                                                               0
# dec_32                                                              0
# Emails              ['abusecomplaints@markmonitor.com', 'whoisrequ...
# numeric_percentage                                                0.0
# puny_coded                                                          0
# typos                    [('google.com', 100), ('google.com.br', 95)]
# oc_8                                                                0
# 3gram                                    ['goo', 'oog', 'ogl', 'gle']
# char_distribution   defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'g...
# 2gram                                  ['go', 'oo', 'og', 'gl', 'le']
# Registrar                                            MarkMonitor inc.
# sld                                                            google
# Name_Server_Count                                                 8.0
# Page_Rank                                                        -1.0
# label                                                               0
# Year                                                           1997.0
# Month                                                             9.0
#
#                                                                     2
# Country                                                           NaN
# ASN                                                               NaN
# TTL                                                                38
# IP                                                                NaN
# Domain                                             b'www.google.com.'
# State                                                             NaN
# Country.1                                                         NaN
# hex_32                                                              0
# hex_8                                                               0
# Domain_Name                                                GOOGLE.COM
# Alexa_Rank                                                        1.0
# subdomain                                                           1
# Organization                                                      NaN
# len                                                                10
# longest_word                                                   google
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                                  ['g', 'o', 'o', 'g', 'l', 'e']
# obfuscate_at_sign                                                 0.0
# entropy                                            2.1142465351822795
# Domain_Age                                                     8256.0
# tld                                                               com
# dec_8                                                               0
# dec_32                                                              0
# Emails                                abusecomplaints@markmonitor.com
# numeric_percentage                                                0.0
# puny_coded                                                          0
# typos                    [('google.com', 100), ('google.com.br', 95)]
# oc_8                                                                0
# 3gram                                    ['goo', 'oog', 'ogl', 'gle']
# char_distribution   defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'w...
# 2gram                                  ['go', 'oo', 'og', 'gl', 'le']
# Registrar                                            MarkMonitor Inc.
# sld                                                            google
# Name_Server_Count                                                 4.0
# Page_Rank                                                        -1.0
# label                                                               0
# Year                                                           1997.0
# Month                                                             9.0

# %%
# Determine which columns can be converted to numeric data type
numerical_columns = ['TTL','hex_32','hex_8', 'Alexa_Rank', 'subdomain', 'len', 'oc_32', 'shortened', 'entropy', 'obfuscate_at_sign', 'ASN', 
                     'dec_8', 'dec_32', 'numeric_percentage', 'puny_coded', 'oc_8', 'Name_Server_Count', 'Page_Rank', 'Year', 'Month', 'label', 'Domain_Age']

# %%
# Convert to numeric data type
df_concat[numerical_columns] = df_concat[numerical_columns].apply(pd.to_numeric, errors='coerce')

# %%
# Determine which columns are categorical data type by dropping numeric columns
categorical_columns = df_concat.drop(columns=numerical_columns).columns

# %%
df_concat[numerical_columns]
# Out:
#           TTL  hex_32  hex_8  Alexa_Rank  subdomain   len  oc_32  shortened  \
# 0        46.0     0.0    0.0         1.0        0.0   7.0    0.0       -1.0
# 1       299.0     0.0    0.0         1.0        0.0   7.0    0.0       -1.0
# 2        38.0     0.0    0.0         1.0        1.0  10.0    0.0       -1.0
# 3       299.0     0.0    0.0         NaN        1.0  10.0    0.0       -1.0
# 4        96.0     0.0    0.0         4.0        0.0   9.0    0.0       -1.0
# ...       ...     ...    ...         ...        ...   ...    ...        ...
# 4994  14399.0     0.0    0.0         NaN        0.0  17.0    0.0       -1.0
# 4995   3599.0     0.0    0.0      3851.0        1.0  32.0    0.0       -1.0
# 4996   3599.0     0.0    0.0      3851.0        1.0  32.0    0.0       -1.0
# 4997   1799.0     0.0    0.0        -1.0        0.0  18.0    0.0       -1.0
# 4998   1799.0     0.0    0.0   5004230.0        1.0  11.0    0.0       -1.0
#
#        entropy  obfuscate_at_sign  ...  dec_32  numeric_percentage  \
# 0     1.834876                0.0  ...     0.0            0.000000
# 1     1.834876                0.0  ...     0.0            0.000000
# 2     2.114247                0.0  ...     0.0            0.000000
# 3     2.114247                0.0  ...     0.0            0.000000
# 4     2.595489                0.0  ...     0.0            0.000000
# ...        ...                ...  ...     ...                 ...
# 4994  2.890279                0.0  ...     0.0            0.000000
# 4995  3.808768                0.0  ...     0.0            7.894737
# 4996  3.808768                0.0  ...     0.0            7.894737
# 4997  3.340769                0.0  ...     0.0            0.000000
# 4998  2.781301                0.0  ...     0.0            0.000000
#
#       puny_coded  oc_8  Name_Server_Count  Page_Rank    Year  Month  label  \
# 0            0.0   0.0                8.0       -1.0  1997.0    9.0      0
# 1            0.0   0.0                8.0       -1.0  1997.0    9.0      0
# 2            0.0   0.0                4.0       -1.0  1997.0    9.0      0
# 3            0.0   0.0                NaN        NaN     NaN    NaN      0
# 4            0.0   0.0                4.0       -1.0  1997.0    3.0      0
# ...          ...   ...                ...        ...     ...    ...    ...
# 4994         0.0   0.0                NaN        NaN     NaN    NaN      1
# 4995         0.0   0.0                4.0       -1.0  2016.0    5.0      1
# 4996         0.0   0.0                4.0       -1.0  2016.0    5.0      1
# 4997         0.0   0.0                0.0       -1.0     NaN    NaN      1
# 4998         0.0   0.0                0.0       -1.0     NaN    NaN      1
#
#       Domain_Age
# 0         8256.0
# 1         8256.0
# 2         8256.0
# 3            NaN
# 4         8426.0
# ...          ...
# 4994         NaN
# 4995      1440.0
# 4996      1440.0
# 4997         NaN
# 4998         NaN
#
# [483590 rows x 22 columns]

# %%
df_concat[categorical_columns].T
# Out:
#                                                                 0     \
# Country                                                           US
# IP                                                     172.217.1.174
# Domain                                                b'google.com.'
# State                                                             CA
# Country.1                                                         US
# Domain_Name                             ['GOOGLE.COM', 'google.com']
# Organization                                              Google LLC
# longest_word                                                  google
# 1gram                                 ['g', 'o', 'o', 'g', 'l', 'e']
# tld                                                              com
# Emails             ['abusecomplaints@markmonitor.com', 'whoisrequ...
# typos                   [('google.com', 100), ('google.com.br', 95)]
# 3gram                                   ['goo', 'oog', 'ogl', 'gle']
# char_distribution  defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'g...
# 2gram                                 ['go', 'oo', 'og', 'gl', 'le']
# Registrar                                           MarkMonitor inc.
# sld                                                           google
#
#                                                                 1     \
# Country                                                          NaN
# IP                                                               NaN
# Domain                                                b'google.com.'
# State                                                             CA
# Country.1                                                         US
# Domain_Name                             ['GOOGLE.COM', 'google.com']
# Organization                                              Google LLC
# longest_word                                                  google
# 1gram                                 ['g', 'o', 'o', 'g', 'l', 'e']
# tld                                                              com
# Emails             ['abusecomplaints@markmonitor.com', 'whoisrequ...
# typos                   [('google.com', 100), ('google.com.br', 95)]
# 3gram                                   ['goo', 'oog', 'ogl', 'gle']
# char_distribution  defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'g...
# 2gram                                 ['go', 'oo', 'og', 'gl', 'le']
# Registrar                                           MarkMonitor inc.
# sld                                                           google
#
#                                                                 2     \
# Country                                                          NaN
# IP                                                               NaN
# Domain                                            b'www.google.com.'
# State                                                            NaN
# Country.1                                                        NaN
# Domain_Name                                               GOOGLE.COM
# Organization                                                     NaN
# longest_word                                                  google
# 1gram                                 ['g', 'o', 'o', 'g', 'l', 'e']
# tld                                                              com
# Emails                               abusecomplaints@markmonitor.com
# typos                   [('google.com', 100), ('google.com.br', 95)]
# 3gram                                   ['goo', 'oog', 'ogl', 'gle']
# char_distribution  defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'w...
# 2gram                                 ['go', 'oo', 'og', 'gl', 'le']
# Registrar                                           MarkMonitor Inc.
# sld                                                           google
#
#                                                                 3     \
# Country                                                           US
# IP                                                   172.217.164.228
# Domain                                            b'www.google.com.'
# State                                                            NaN
# Country.1                                                        NaN
# Domain_Name                                                      NaN
# Organization                                                     NaN
# longest_word                                                  google
# 1gram                                 ['g', 'o', 'o', 'g', 'l', 'e']
# tld                                                              com
# Emails                                                           NaN
# typos                   [('google.com', 100), ('google.com.br', 95)]
# 3gram                                   ['goo', 'oog', 'ogl', 'gle']
# char_distribution  defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'w...
# 2gram                                 ['go', 'oo', 'og', 'gl', 'le']
# Registrar                                                        NaN
# sld                                                           google
#
#                                                                 4     \
# Country                                                          NaN
# IP                                                               NaN
# Domain                                              b'facebook.com.'
# State                                                             CA
# Country.1                                                         US
# Domain_Name                                             FACEBOOK.COM
# Organization                                           Facebook inc.
# longest_word                                                facebook
# 1gram                       ['f', 'a', 'c', 'e', 'b', 'o', 'o', 'k']
# tld                                                              com
# Emails             ['abusecomplaints@registrarsafe.com', 'domain@...
# typos                        [('facebook.com', 100), ('qq.com', 86)]
# 3gram                     ['fac', 'ace', 'ceb', 'ebo', 'boo', 'ook']
# char_distribution  defaultdict(<class 'int'>, {'e': 1, 'c': 1, 'o...
# 2gram                     ['fa', 'ac', 'ce', 'eb', 'bo', 'oo', 'ok']
# Registrar                                          RegistrarSafe LLC
# sld                                                         facebook
#
#                                                                 5     \
# Country                                                           IE
# IP                                                       31.13.80.36
# Domain                                              b'facebook.com.'
# State                                                             CA
# Country.1                                                         US
# Domain_Name                                             FACEBOOK.COM
# Organization                                           Facebook inc.
# longest_word                                                facebook
# 1gram                       ['f', 'a', 'c', 'e', 'b', 'o', 'o', 'k']
# tld                                                              com
# Emails             ['abusecomplaints@registrarsafe.com', 'domain@...
# typos                        [('facebook.com', 100), ('qq.com', 86)]
# 3gram                     ['fac', 'ace', 'ceb', 'ebo', 'boo', 'ook']
# char_distribution  defaultdict(<class 'int'>, {'e': 1, 'c': 1, 'o...
# 2gram                     ['fa', 'ac', 'ce', 'eb', 'bo', 'oo', 'ok']
# Registrar                                          RegistrarSafe LLC
# sld                                                         facebook
#
#                                                                 6     \
# Country                                                          NaN
# IP                                                               NaN
# Domain                                              b'facebook.com.'
# State                                                             CA
# Country.1                                                         US
# Domain_Name                                             FACEBOOK.COM
# Organization                                           Facebook inc.
# longest_word                                                facebook
# 1gram                       ['f', 'a', 'c', 'e', 'b', 'o', 'o', 'k']
# tld                                                              com
# Emails             ['abusecomplaints@registrarsafe.com', 'domain@...
# typos                        [('facebook.com', 100), ('qq.com', 86)]
# 3gram                     ['fac', 'ace', 'ceb', 'ebo', 'boo', 'ook']
# char_distribution  defaultdict(<class 'int'>, {'e': 1, 'c': 1, 'o...
# 2gram                     ['fa', 'ac', 'ce', 'eb', 'bo', 'oo', 'ok']
# Registrar                                          RegistrarSafe LLC
# sld                                                         facebook
#
#                                                                 7     \
# Country                                                           IE
# IP                                                       31.13.80.36
# Domain                                              b'facebook.com.'
# State                                                             CA
# Country.1                                                         US
# Domain_Name                                             FACEBOOK.COM
# Organization                                           Facebook inc.
# longest_word                                                facebook
# 1gram                       ['f', 'a', 'c', 'e', 'b', 'o', 'o', 'k']
# tld                                                              com
# Emails             ['abusecomplaints@registrarsafe.com', 'domain@...
# typos                        [('facebook.com', 100), ('qq.com', 86)]
# 3gram                     ['fac', 'ace', 'ceb', 'ebo', 'boo', 'ook']
# char_distribution  defaultdict(<class 'int'>, {'e': 1, 'c': 1, 'o...
# 2gram                     ['fa', 'ac', 'ce', 'eb', 'bo', 'oo', 'ok']
# Registrar                                          RegistrarSafe LLC
# sld                                                         facebook
#
#                                                                 8     \
# Country                                                           IE
# IP                                                       31.13.71.36
# Domain                                          b'www.facebook.com.'
# State                                                             CA
# Country.1                                                         US
# Domain_Name                                             FACEBOOK.COM
# Organization                                           Facebook inc.
# longest_word                                                facebook
# 1gram                       ['f', 'a', 'c', 'e', 'b', 'o', 'o', 'k']
# tld                                                              com
# Emails             ['abusecomplaints@registrarsafe.com', 'domain@...
# typos                        [('facebook.com', 100), ('qq.com', 86)]
# 3gram                     ['fac', 'ace', 'ceb', 'ebo', 'boo', 'ook']
# char_distribution  defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'f...
# 2gram                     ['fa', 'ac', 'ce', 'eb', 'bo', 'oo', 'ok']
# Registrar                                          RegistrarSafe LLC
# sld                                                         facebook
#
#                                                                 9     ...  \
# Country                                                          NaN  ...
# IP                                                               NaN  ...
# Domain                                          b'www.facebook.com.'  ...
# State                                                             CA  ...
# Country.1                                                         US  ...
# Domain_Name                                             FACEBOOK.COM  ...
# Organization                                           Facebook inc.  ...
# longest_word                                                facebook  ...
# 1gram                       ['f', 'a', 'c', 'e', 'b', 'o', 'o', 'k']  ...
# tld                                                              com  ...
# Emails             ['abusecomplaints@registrarsafe.com', 'domain@...  ...
# typos                        [('facebook.com', 100), ('qq.com', 86)]  ...
# 3gram                     ['fac', 'ace', 'ceb', 'ebo', 'boo', 'ook']  ...
# char_distribution  defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'f...  ...
# 2gram                     ['fa', 'ac', 'ce', 'eb', 'bo', 'oo', 'ok']  ...
# Registrar                                          RegistrarSafe LLC  ...
# sld                                                         facebook  ...
#
#                                                                 4989  \
# Country                                                           US
# IP                                                    74.206.232.234
# Domain             b'facebook.com-------mobile---read---new--term...
# State                                                            NaN
# Country.1                                                        NaN
# Domain_Name                                             PERALTEK.COM
# Organization                                                     NaN
# longest_word                                                    ltek
# 1gram                       ['p', 'e', 'r', 'a', 'l', 't', 'e', 'k']
# tld                                                              com
# Emails                                                           NaN
# typos                               [('qq.com', 86), ('vk.com', 86)]
# 3gram                     ['per', 'era', 'ral', 'alt', 'lte', 'tek']
# char_distribution  defaultdict(<class 'int'>, {'-': 17, 'd': 1, '...
# 2gram                     ['pe', 'er', 'ra', 'al', 'lt', 'te', 'ek']
# Registrar                                                   eNom LLC
# sld                                                         peraltek
#
#                                                                 4990  \
# Country                                                           HU
# IP                                                     62.112.194.97
# Domain                                             b'globocomm.org.'
# State                                                            NaN
# Country.1                                                         HU
# Domain_Name                                            GLOBOCOMM.ORG
# Organization                                            Educomm Ltd.
# longest_word                                                   globo
# 1gram                  ['g', 'l', 'o', 'b', 'o', 'c', 'o', 'm', 'm']
# tld                                                              org
# Emails                                     legalservices@eurodns.com
# typos                              [('w3.org', 86), ('npr.org', 86)]
# 3gram              ['glo', 'lob', 'obo', 'boc', 'oco', 'com', 'omm']
# char_distribution  defaultdict(<class 'int'>, {'g': 1, 'm': 2, 'b...
# 2gram               ['gl', 'lo', 'ob', 'bo', 'oc', 'co', 'om', 'mm']
# Registrar                                               EuroDNS S.A.
# sld                                                        globocomm
#
#                                                                 4991  \
# Country                                                           HU
# IP                                                     62.112.194.97
# Domain                                             b'globocomm.org.'
# State                                                            NaN
# Country.1                                                         HU
# Domain_Name                                            GLOBOCOMM.ORG
# Organization                                            Educomm Ltd.
# longest_word                                                   globo
# 1gram                  ['g', 'l', 'o', 'b', 'o', 'c', 'o', 'm', 'm']
# tld                                                              org
# Emails                                     legalservices@eurodns.com
# typos                              [('w3.org', 86), ('npr.org', 86)]
# 3gram              ['glo', 'lob', 'obo', 'boc', 'oco', 'com', 'omm']
# char_distribution  defaultdict(<class 'int'>, {'g': 1, 'm': 2, 'b...
# 2gram               ['gl', 'lo', 'ob', 'bo', 'oc', 'co', 'om', 'mm']
# Registrar                                               EuroDNS S.A.
# sld                                                        globocomm
#
#                                                                 4992  \
# Country                                                           HU
# IP                                                     62.112.194.97
# Domain                                         b'www.globocomm.org.'
# State                                                            NaN
# Country.1                                                         HU
# Domain_Name                                            GLOBOCOMM.ORG
# Organization                                            Educomm Ltd.
# longest_word                                                   globo
# 1gram                  ['g', 'l', 'o', 'b', 'o', 'c', 'o', 'm', 'm']
# tld                                                              org
# Emails                                     legalservices@eurodns.com
# typos                              [('w3.org', 86), ('npr.org', 86)]
# 3gram              ['glo', 'lob', 'obo', 'boc', 'oco', 'com', 'omm']
# char_distribution  defaultdict(<class 'int'>, {'g': 1, 'm': 2, 'b...
# 2gram               ['gl', 'lo', 'ob', 'bo', 'oc', 'co', 'om', 'mm']
# Registrar                                               EuroDNS S.A.
# sld                                                        globocomm
#
#                                                                 4993  \
# Country                                                           NL
# IP                                                    145.14.145.115
# Domain                                b'jokowi12.000webhostapp.com.'
# State                                                        Larnaka
# Country.1                                                         CY
# Domain_Name                                        000WEBHOSTAPP.COM
# Organization                                             GDPR Masked
# longest_word                                                       p
# 1gram              ['0', '0', '0', 'w', 'e', 'b', 'h', 'o', 's', ...
# tld                                                              com
# Emails             ['abuse@hostinger.com', 'gdpr-masking@gdpr-mas...
# typos                      [('twitter.com', 86), ('google.com', 86)]
# 3gram              ['000', '00w', '0we', 'web', 'ebh', 'bho', 'ho...
# char_distribution  defaultdict(<class 'int'>, {'1': 1, '2': 1, 'w...
# 2gram              ['00', '00', '0w', 'we', 'eb', 'bh', 'ho', 'os...
# Registrar                                              Hostinger UAB
# sld                                                    000webhostapp
#
#                                                                 4994  \
# Country                                                           DE
# IP                                                    148.251.70.130
# Domain                                      b'naveenmechanical.com.'
# State                                                            NaN
# Country.1                                                        NaN
# Domain_Name                                                      NaN
# Organization                                                     NaN
# longest_word                                              mechanical
# 1gram              ['n', 'a', 'v', 'e', 'e', 'n', 'm', 'e', 'c', ...
# tld                                                              com
# Emails                                                           NaN
# typos                    [('facebook.com', 86), ('twitter.com', 86)]
# 3gram              ['nav', 'ave', 'vee', 'een', 'enm', 'nme', 'me...
# char_distribution  defaultdict(<class 'int'>, {'v': 1, 'n': 3, 'e...
# 2gram              ['na', 'av', 've', 'ee', 'en', 'nm', 'me', 'ec...
# Registrar                                                        NaN
# sld                                                 naveenmechanical
#
#                                                                 4995  \
# Country                                                           NL
# IP                                                     145.14.145.85
# Domain                      b'onlinefrepdfviewer.000webhostapp.com.'
# State                                                        Larnaka
# Country.1                                                         CY
# Domain_Name                                        000WEBHOSTAPP.COM
# Organization                                             GDPR Masked
# longest_word                                                       p
# 1gram              ['0', '0', '0', 'w', 'e', 'b', 'h', 'o', 's', ...
# tld                                                              com
# Emails             ['abuse@hostinger.com', 'gdpr-masking@gdpr-mas...
# typos                      [('twitter.com', 86), ('google.com', 86)]
# 3gram              ['000', '00w', '0we', 'web', 'ebh', 'bho', 'ho...
# char_distribution  defaultdict(<class 'int'>, {'d': 1, 'n': 2, 'r...
# 2gram              ['00', '00', '0w', 'we', 'eb', 'bh', 'ho', 'os...
# Registrar                                              Hostinger UAB
# sld                                                    000webhostapp
#
#                                                                 4996  \
# Country                                                          NaN
# IP                                                               NaN
# Domain                      b'onlinefrepdfviewer.000webhostapp.com.'
# State                                                        Larnaka
# Country.1                                                         CY
# Domain_Name                                        000WEBHOSTAPP.COM
# Organization                                             GDPR Masked
# longest_word                                                       p
# 1gram              ['0', '0', '0', 'w', 'e', 'b', 'h', 'o', 's', ...
# tld                                                              com
# Emails             ['abuse@hostinger.com', 'gdpr-masking@gdpr-mas...
# typos                      [('twitter.com', 86), ('google.com', 86)]
# 3gram              ['000', '00w', '0we', 'web', 'ebh', 'bho', 'ho...
# char_distribution  defaultdict(<class 'int'>, {'d': 1, 'n': 2, 'r...
# 2gram              ['00', '00', '0w', 'we', 'eb', 'bh', 'ho', 'os...
# Registrar                                              Hostinger UAB
# sld                                                    000webhostapp
#
#                                                                 4997  \
# Country                                                           DE
# IP                                                     62.245.182.18
# Domain                                      b'stefanie-bolemant.de.'
# State                                                            NaN
# Country.1                                                        NaN
# Domain_Name                                     stefanie-bolemant.de
# Organization                                                     NaN
# longest_word                                                stefanie
# 1gram              ['s', 't', 'e', 'f', 'a', 'n', 'i', 'e', '-', ...
# tld                                                               de
# Emails                                                           NaN
# typos                      [('google.de', 86), ('e-recht24.de', 86)]
# 3gram              ['ste', 'tef', 'efa', 'fan', 'ani', 'nie', 'ie...
# char_distribution  defaultdict(<class 'int'>, {'-': 1, 'n': 2, 'm...
# 2gram              ['st', 'te', 'ef', 'fa', 'an', 'ni', 'ie', 'e-...
# Registrar                                                        NaN
# sld                                                stefanie-bolemant
#
#                                                                 4998
# Country                                                           DE
# IP                                                     62.245.182.48
# Domain                                            b'web.asamnet.de.'
# State                                                            NaN
# Country.1                                                        NaN
# Domain_Name                                               asamnet.de
# Organization                                                     NaN
# longest_word                                                    mnet
# 1gram                            ['a', 's', 'a', 'm', 'n', 'e', 't']
# tld                                                               de
# Emails                                                           NaN
# typos               [('gesetze-im-internet.de', 86), ('web.de', 86)]
# 3gram                            ['asa', 'sam', 'amn', 'mne', 'net']
# char_distribution  defaultdict(<class 'int'>, {'t': 1, 'n': 1, 'a...
# 2gram                           ['as', 'sa', 'am', 'mn', 'ne', 'et']
# Registrar                                                        NaN
# sld                                                          asamnet
#
# [17 rows x 483590 columns]

# %%
# Create summary of Nan and unique values counts for categorical data
data_summary(df_concat[categorical_columns])
# Out:
#                    nan_count  nan_percentage  Unique_val count  \
# Country               105610            21.8               285
# IP                    104335            21.6            177855
# Domain                     0             0.0            313538
# State                 263453            54.5              5814
# Country.1             227474            47.0              1620
# Domain_Name            87007            18.0            195952
# Organization          279730            57.8             39735
# longest_word             129             0.0             34204
# 1gram                     22             0.0            211753
# tld                        3             0.0             31786
# Emails                158504            32.8             44745
# typos                      0             0.0             30268
# 3gram                      0             0.0            210746
# char_distribution          0             0.0            284881
# 2gram                    175             0.0            229924
# Registrar             126965            26.3             17290
# sld                     1326             0.3            177014
#
#                    unique_percentage  Zero values count Data type
# Country                          0.1                  0    object
# IP                              36.8                  0    object
# Domain                          64.8                  0    object
# State                            1.2                  0    object
# Country.1                        0.3                  0    object
# Domain_Name                     40.5                  0    object
# Organization                     8.2                  0    object
# longest_word                     7.1                  0    object
# 1gram                           43.8                  0    object
# tld                              6.6                  0    object
# Emails                           9.3                  0    object
# typos                            6.3                  0    object
# 3gram                           43.6                  0    object
# char_distribution               58.9                  0    object
# 2gram                           47.5                  0    object
# Registrar                        3.6                  0    object
# sld                             36.6                  0    object

# %%
# regex_pattern = "b'?(www.)?(.*?)\.'"
# df_concat['Domain'] = df_concat['Domain'].str.extract(regex_pattern)

# %%
# Most indexes are duplicated
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 483590 entries, 0 to 4998
# Data columns (total 39 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Country             377980 non-null  object
#  1   ASN                 378035 non-null  float64
#  2   TTL                 483566 non-null  float64
#  3   IP                  379255 non-null  object
#  4   Domain              483590 non-null  object
#  5   State               220137 non-null  object
#  6   Country.1           256116 non-null  object
#  7   hex_32              483220 non-null  float64
#  8   hex_8               483563 non-null  float64
#  9   Domain_Name         396583 non-null  object
#  10  Alexa_Rank          434831 non-null  float64
#  11  subdomain           483461 non-null  float64
#  12  Organization        203860 non-null  object
#  13  len                 452572 non-null  float64
#  14  longest_word        483461 non-null  object
#  15  oc_32               452816 non-null  float64
#  16  shortened           482102 non-null  float64
#  17  1gram               483568 non-null  object
#  18  obfuscate_at_sign   452740 non-null  float64
#  19  entropy             483412 non-null  float64
#  20  Domain_Age          332404 non-null  float64
#  21  tld                 483587 non-null  object
#  22  dec_8               452701 non-null  float64
#  23  dec_32              483102 non-null  float64
#  24  Emails              325086 non-null  object
#  25  numeric_percentage  451505 non-null  float64
#  26  puny_coded          483099 non-null  float64
#  27  typos               483590 non-null  object
#  28  oc_8                451014 non-null  float64
#  29  3gram               483590 non-null  object
#  30  char_distribution   483590 non-null  object
#  31  2gram               483415 non-null  object
#  32  Registrar           356625 non-null  object
#  33  sld                 482264 non-null  object
#  34  Name_Server_Count   336082 non-null  float64
#  35  Page_Rank           434720 non-null  float64
#  36  label               483590 non-null  int64
#  37  Year                362665 non-null  float64
#  38  Month               362665 non-null  float64
# dtypes: float64(21), int64(1), object(17)
# memory usage: 163.7+ MB

# %%
# Reset index
df_concat.reset_index(drop=True, inplace=True)

# %%
df_concat.T
# Out:
#                                                                0       \
# Country                                                            US
# ASN                                                           15169.0
# TTL                                                              46.0
# IP                                                      172.217.1.174
# Domain                                                 b'google.com.'
# State                                                              CA
# Country.1                                                          US
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                              ['GOOGLE.COM', 'google.com']
# Alexa_Rank                                                        1.0
# subdomain                                                         0.0
# Organization                                               Google LLC
# len                                                               7.0
# longest_word                                                   google
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                                  ['g', 'o', 'o', 'g', 'l', 'e']
# obfuscate_at_sign                                                 0.0
# entropy                                                      1.834876
# Domain_Age                                                     8256.0
# tld                                                               com
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails              ['abusecomplaints@markmonitor.com', 'whoisrequ...
# numeric_percentage                                                0.0
# puny_coded                                                        0.0
# typos                    [('google.com', 100), ('google.com.br', 95)]
# oc_8                                                              0.0
# 3gram                                    ['goo', 'oog', 'ogl', 'gle']
# char_distribution   defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'g...
# 2gram                                  ['go', 'oo', 'og', 'gl', 'le']
# Registrar                                            MarkMonitor inc.
# sld                                                            google
# Name_Server_Count                                                 8.0
# Page_Rank                                                        -1.0
# label                                                               0
# Year                                                           1997.0
# Month                                                             9.0
#
#                                                                1       \
# Country                                                           NaN
# ASN                                                               NaN
# TTL                                                             299.0
# IP                                                                NaN
# Domain                                                 b'google.com.'
# State                                                              CA
# Country.1                                                          US
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                              ['GOOGLE.COM', 'google.com']
# Alexa_Rank                                                        1.0
# subdomain                                                         0.0
# Organization                                               Google LLC
# len                                                               7.0
# longest_word                                                   google
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                                  ['g', 'o', 'o', 'g', 'l', 'e']
# obfuscate_at_sign                                                 0.0
# entropy                                                      1.834876
# Domain_Age                                                     8256.0
# tld                                                               com
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails              ['abusecomplaints@markmonitor.com', 'whoisrequ...
# numeric_percentage                                                0.0
# puny_coded                                                        0.0
# typos                    [('google.com', 100), ('google.com.br', 95)]
# oc_8                                                              0.0
# 3gram                                    ['goo', 'oog', 'ogl', 'gle']
# char_distribution   defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'g...
# 2gram                                  ['go', 'oo', 'og', 'gl', 'le']
# Registrar                                            MarkMonitor inc.
# sld                                                            google
# Name_Server_Count                                                 8.0
# Page_Rank                                                        -1.0
# label                                                               0
# Year                                                           1997.0
# Month                                                             9.0
#
#                                                                2       \
# Country                                                           NaN
# ASN                                                               NaN
# TTL                                                              38.0
# IP                                                                NaN
# Domain                                             b'www.google.com.'
# State                                                             NaN
# Country.1                                                         NaN
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                                                GOOGLE.COM
# Alexa_Rank                                                        1.0
# subdomain                                                         1.0
# Organization                                                      NaN
# len                                                              10.0
# longest_word                                                   google
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                                  ['g', 'o', 'o', 'g', 'l', 'e']
# obfuscate_at_sign                                                 0.0
# entropy                                                      2.114247
# Domain_Age                                                     8256.0
# tld                                                               com
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails                                abusecomplaints@markmonitor.com
# numeric_percentage                                                0.0
# puny_coded                                                        0.0
# typos                    [('google.com', 100), ('google.com.br', 95)]
# oc_8                                                              0.0
# 3gram                                    ['goo', 'oog', 'ogl', 'gle']
# char_distribution   defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'w...
# 2gram                                  ['go', 'oo', 'og', 'gl', 'le']
# Registrar                                            MarkMonitor Inc.
# sld                                                            google
# Name_Server_Count                                                 4.0
# Page_Rank                                                        -1.0
# label                                                               0
# Year                                                           1997.0
# Month                                                             9.0
#
#                                                                3       \
# Country                                                            US
# ASN                                                           15169.0
# TTL                                                             299.0
# IP                                                    172.217.164.228
# Domain                                             b'www.google.com.'
# State                                                             NaN
# Country.1                                                         NaN
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                                                       NaN
# Alexa_Rank                                                        NaN
# subdomain                                                         1.0
# Organization                                                      NaN
# len                                                              10.0
# longest_word                                                   google
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                                  ['g', 'o', 'o', 'g', 'l', 'e']
# obfuscate_at_sign                                                 0.0
# entropy                                                      2.114247
# Domain_Age                                                        NaN
# tld                                                               com
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails                                                            NaN
# numeric_percentage                                                0.0
# puny_coded                                                        0.0
# typos                    [('google.com', 100), ('google.com.br', 95)]
# oc_8                                                              0.0
# 3gram                                    ['goo', 'oog', 'ogl', 'gle']
# char_distribution   defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'w...
# 2gram                                  ['go', 'oo', 'og', 'gl', 'le']
# Registrar                                                         NaN
# sld                                                            google
# Name_Server_Count                                                 NaN
# Page_Rank                                                         NaN
# label                                                               0
# Year                                                              NaN
# Month                                                             NaN
#
#                                                                4       \
# Country                                                           NaN
# ASN                                                               NaN
# TTL                                                              96.0
# IP                                                                NaN
# Domain                                               b'facebook.com.'
# State                                                              CA
# Country.1                                                          US
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                                              FACEBOOK.COM
# Alexa_Rank                                                        4.0
# subdomain                                                         0.0
# Organization                                            Facebook inc.
# len                                                               9.0
# longest_word                                                 facebook
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                        ['f', 'a', 'c', 'e', 'b', 'o', 'o', 'k']
# obfuscate_at_sign                                                 0.0
# entropy                                                      2.595489
# Domain_Age                                                     8426.0
# tld                                                               com
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails              ['abusecomplaints@registrarsafe.com', 'domain@...
# numeric_percentage                                                0.0
# puny_coded                                                        0.0
# typos                         [('facebook.com', 100), ('qq.com', 86)]
# oc_8                                                              0.0
# 3gram                      ['fac', 'ace', 'ceb', 'ebo', 'boo', 'ook']
# char_distribution   defaultdict(<class 'int'>, {'e': 1, 'c': 1, 'o...
# 2gram                      ['fa', 'ac', 'ce', 'eb', 'bo', 'oo', 'ok']
# Registrar                                           RegistrarSafe LLC
# sld                                                          facebook
# Name_Server_Count                                                 4.0
# Page_Rank                                                        -1.0
# label                                                               0
# Year                                                           1997.0
# Month                                                             3.0
#
#                                                                5       \
# Country                                                            IE
# ASN                                                           32934.0
# TTL                                                             264.0
# IP                                                        31.13.80.36
# Domain                                               b'facebook.com.'
# State                                                              CA
# Country.1                                                          US
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                                              FACEBOOK.COM
# Alexa_Rank                                                        4.0
# subdomain                                                         0.0
# Organization                                            Facebook inc.
# len                                                               9.0
# longest_word                                                 facebook
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                        ['f', 'a', 'c', 'e', 'b', 'o', 'o', 'k']
# obfuscate_at_sign                                                 0.0
# entropy                                                      2.595489
# Domain_Age                                                     8426.0
# tld                                                               com
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails              ['abusecomplaints@registrarsafe.com', 'domain@...
# numeric_percentage                                                0.0
# puny_coded                                                        0.0
# typos                         [('facebook.com', 100), ('qq.com', 86)]
# oc_8                                                              0.0
# 3gram                      ['fac', 'ace', 'ceb', 'ebo', 'boo', 'ook']
# char_distribution   defaultdict(<class 'int'>, {'e': 1, 'c': 1, 'o...
# 2gram                      ['fa', 'ac', 'ce', 'eb', 'bo', 'oo', 'ok']
# Registrar                                           RegistrarSafe LLC
# sld                                                          facebook
# Name_Server_Count                                                 4.0
# Page_Rank                                                        -1.0
# label                                                               0
# Year                                                           1997.0
# Month                                                             3.0
#
#                                                                6       \
# Country                                                           NaN
# ASN                                                               NaN
# TTL                                                             299.0
# IP                                                                NaN
# Domain                                               b'facebook.com.'
# State                                                              CA
# Country.1                                                          US
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                                              FACEBOOK.COM
# Alexa_Rank                                                        4.0
# subdomain                                                         0.0
# Organization                                            Facebook inc.
# len                                                               9.0
# longest_word                                                 facebook
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                        ['f', 'a', 'c', 'e', 'b', 'o', 'o', 'k']
# obfuscate_at_sign                                                 0.0
# entropy                                                      2.595489
# Domain_Age                                                     8426.0
# tld                                                               com
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails              ['abusecomplaints@registrarsafe.com', 'domain@...
# numeric_percentage                                                0.0
# puny_coded                                                        0.0
# typos                         [('facebook.com', 100), ('qq.com', 86)]
# oc_8                                                              0.0
# 3gram                      ['fac', 'ace', 'ceb', 'ebo', 'boo', 'ook']
# char_distribution   defaultdict(<class 'int'>, {'e': 1, 'c': 1, 'o...
# 2gram                      ['fa', 'ac', 'ce', 'eb', 'bo', 'oo', 'ok']
# Registrar                                           RegistrarSafe LLC
# sld                                                          facebook
# Name_Server_Count                                                 4.0
# Page_Rank                                                        -1.0
# label                                                               0
# Year                                                           1997.0
# Month                                                             3.0
#
#                                                                7       \
# Country                                                            IE
# ASN                                                           32934.0
# TTL                                                             299.0
# IP                                                        31.13.80.36
# Domain                                               b'facebook.com.'
# State                                                              CA
# Country.1                                                          US
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                                              FACEBOOK.COM
# Alexa_Rank                                                        4.0
# subdomain                                                         0.0
# Organization                                            Facebook inc.
# len                                                               9.0
# longest_word                                                 facebook
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                        ['f', 'a', 'c', 'e', 'b', 'o', 'o', 'k']
# obfuscate_at_sign                                                 0.0
# entropy                                                      2.595489
# Domain_Age                                                     8426.0
# tld                                                               com
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails              ['abusecomplaints@registrarsafe.com', 'domain@...
# numeric_percentage                                                0.0
# puny_coded                                                        0.0
# typos                         [('facebook.com', 100), ('qq.com', 86)]
# oc_8                                                              0.0
# 3gram                      ['fac', 'ace', 'ceb', 'ebo', 'boo', 'ook']
# char_distribution   defaultdict(<class 'int'>, {'e': 1, 'c': 1, 'o...
# 2gram                      ['fa', 'ac', 'ce', 'eb', 'bo', 'oo', 'ok']
# Registrar                                           RegistrarSafe LLC
# sld                                                          facebook
# Name_Server_Count                                                 4.0
# Page_Rank                                                        -1.0
# label                                                               0
# Year                                                           1997.0
# Month                                                             3.0
#
#                                                                8       \
# Country                                                            IE
# ASN                                                           32934.0
# TTL                                                            3218.0
# IP                                                        31.13.71.36
# Domain                                           b'www.facebook.com.'
# State                                                              CA
# Country.1                                                          US
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                                              FACEBOOK.COM
# Alexa_Rank                                                        4.0
# subdomain                                                         1.0
# Organization                                            Facebook inc.
# len                                                              12.0
# longest_word                                                 facebook
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                        ['f', 'a', 'c', 'e', 'b', 'o', 'o', 'k']
# obfuscate_at_sign                                                 0.0
# entropy                                                      2.723308
# Domain_Age                                                     8426.0
# tld                                                               com
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails              ['abusecomplaints@registrarsafe.com', 'domain@...
# numeric_percentage                                                0.0
# puny_coded                                                        0.0
# typos                         [('facebook.com', 100), ('qq.com', 86)]
# oc_8                                                              0.0
# 3gram                      ['fac', 'ace', 'ceb', 'ebo', 'boo', 'ook']
# char_distribution   defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'f...
# 2gram                      ['fa', 'ac', 'ce', 'eb', 'bo', 'oo', 'ok']
# Registrar                                           RegistrarSafe LLC
# sld                                                          facebook
# Name_Server_Count                                                 4.0
# Page_Rank                                                        -1.0
# label                                                               0
# Year                                                           1997.0
# Month                                                             3.0
#
#                                                                9       ...  \
# Country                                                           NaN  ...
# ASN                                                               NaN  ...
# TTL                                                            3323.0  ...
# IP                                                                NaN  ...
# Domain                                           b'www.facebook.com.'  ...
# State                                                              CA  ...
# Country.1                                                          US  ...
# hex_32                                                            0.0  ...
# hex_8                                                             0.0  ...
# Domain_Name                                              FACEBOOK.COM  ...
# Alexa_Rank                                                        4.0  ...
# subdomain                                                         1.0  ...
# Organization                                            Facebook inc.  ...
# len                                                              12.0  ...
# longest_word                                                 facebook  ...
# oc_32                                                             0.0  ...
# shortened                                                        -1.0  ...
# 1gram                        ['f', 'a', 'c', 'e', 'b', 'o', 'o', 'k']  ...
# obfuscate_at_sign                                                 0.0  ...
# entropy                                                      2.723308  ...
# Domain_Age                                                     8426.0  ...
# tld                                                               com  ...
# dec_8                                                             0.0  ...
# dec_32                                                            0.0  ...
# Emails              ['abusecomplaints@registrarsafe.com', 'domain@...  ...
# numeric_percentage                                                0.0  ...
# puny_coded                                                        0.0  ...
# typos                         [('facebook.com', 100), ('qq.com', 86)]  ...
# oc_8                                                              0.0  ...
# 3gram                      ['fac', 'ace', 'ceb', 'ebo', 'boo', 'ook']  ...
# char_distribution   defaultdict(<class 'int'>, {'e': 1, 'o': 2, 'f...  ...
# 2gram                      ['fa', 'ac', 'ce', 'eb', 'bo', 'oo', 'ok']  ...
# Registrar                                           RegistrarSafe LLC  ...
# sld                                                          facebook  ...
# Name_Server_Count                                                 4.0  ...
# Page_Rank                                                        -1.0  ...
# label                                                               0  ...
# Year                                                           1997.0  ...
# Month                                                             3.0  ...
#
#                                                                483580  \
# Country                                                            US
# ASN                                                           27257.0
# TTL                                                            1799.0
# IP                                                     74.206.232.234
# Domain              b'facebook.com-------mobile---read---new--term...
# State                                                             NaN
# Country.1                                                         NaN
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                                              PERALTEK.COM
# Alexa_Rank                                                       -1.0
# subdomain                                                         1.0
# Organization                                                      NaN
# len                                                              65.0
# longest_word                                                     ltek
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                        ['p', 'e', 'r', 'a', 'l', 't', 'e', 'k']
# obfuscate_at_sign                                                 0.0
# entropy                                                      3.988825
# Domain_Age                                                      398.0
# tld                                                               com
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails                                                            NaN
# numeric_percentage                                          12.676056
# puny_coded                                                        0.0
# typos                                [('qq.com', 86), ('vk.com', 86)]
# oc_8                                                              0.0
# 3gram                      ['per', 'era', 'ral', 'alt', 'lte', 'tek']
# char_distribution   defaultdict(<class 'int'>, {'-': 17, 'd': 1, '...
# 2gram                      ['pe', 'er', 'ra', 'al', 'lt', 'te', 'ek']
# Registrar                                                    eNom LLC
# sld                                                          peraltek
# Name_Server_Count                                                 2.0
# Page_Rank                                                        -1.0
# label                                                               1
# Year                                                           2019.0
# Month                                                             3.0
#
#                                                                483581  \
# Country                                                            HU
# ASN                                                          197248.0
# TTL                                                            3599.0
# IP                                                      62.112.194.97
# Domain                                              b'globocomm.org.'
# State                                                             NaN
# Country.1                                                          HU
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                                             GLOBOCOMM.ORG
# Alexa_Rank                                                       -1.0
# subdomain                                                         0.0
# Organization                                             Educomm Ltd.
# len                                                              10.0
# longest_word                                                    globo
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                   ['g', 'l', 'o', 'b', 'o', 'c', 'o', 'm', 'm']
# obfuscate_at_sign                                                 0.0
# entropy                                                      2.314247
# Domain_Age                                                     2257.0
# tld                                                               org
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails                                      legalservices@eurodns.com
# numeric_percentage                                                0.0
# puny_coded                                                        0.0
# typos                               [('w3.org', 86), ('npr.org', 86)]
# oc_8                                                              0.0
# 3gram               ['glo', 'lob', 'obo', 'boc', 'oco', 'com', 'omm']
# char_distribution   defaultdict(<class 'int'>, {'g': 1, 'm': 2, 'b...
# 2gram                ['gl', 'lo', 'ob', 'bo', 'oc', 'co', 'om', 'mm']
# Registrar                                                EuroDNS S.A.
# sld                                                         globocomm
# Name_Server_Count                                                 2.0
# Page_Rank                                                        -1.0
# label                                                               1
# Year                                                           2014.0
# Month                                                             2.0
#
#                                                                483582  \
# Country                                                            HU
# ASN                                                          197248.0
# TTL                                                            3598.0
# IP                                                      62.112.194.97
# Domain                                              b'globocomm.org.'
# State                                                             NaN
# Country.1                                                          HU
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                                             GLOBOCOMM.ORG
# Alexa_Rank                                                       -1.0
# subdomain                                                         0.0
# Organization                                             Educomm Ltd.
# len                                                              10.0
# longest_word                                                    globo
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                   ['g', 'l', 'o', 'b', 'o', 'c', 'o', 'm', 'm']
# obfuscate_at_sign                                                 0.0
# entropy                                                      2.314247
# Domain_Age                                                     2257.0
# tld                                                               org
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails                                      legalservices@eurodns.com
# numeric_percentage                                                0.0
# puny_coded                                                        0.0
# typos                               [('w3.org', 86), ('npr.org', 86)]
# oc_8                                                              0.0
# 3gram               ['glo', 'lob', 'obo', 'boc', 'oco', 'com', 'omm']
# char_distribution   defaultdict(<class 'int'>, {'g': 1, 'm': 2, 'b...
# 2gram                ['gl', 'lo', 'ob', 'bo', 'oc', 'co', 'om', 'mm']
# Registrar                                                EuroDNS S.A.
# sld                                                         globocomm
# Name_Server_Count                                                 2.0
# Page_Rank                                                        -1.0
# label                                                               1
# Year                                                           2014.0
# Month                                                             2.0
#
#                                                                483583  \
# Country                                                            HU
# ASN                                                          197248.0
# TTL                                                            3599.0
# IP                                                      62.112.194.97
# Domain                                          b'www.globocomm.org.'
# State                                                             NaN
# Country.1                                                          HU
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                                             GLOBOCOMM.ORG
# Alexa_Rank                                                       -1.0
# subdomain                                                         1.0
# Organization                                             Educomm Ltd.
# len                                                              13.0
# longest_word                                                    globo
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                   ['g', 'l', 'o', 'b', 'o', 'c', 'o', 'm', 'm']
# obfuscate_at_sign                                                 0.0
# entropy                                                      2.530423
# Domain_Age                                                     2257.0
# tld                                                               org
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails                                      legalservices@eurodns.com
# numeric_percentage                                                0.0
# puny_coded                                                        0.0
# typos                               [('w3.org', 86), ('npr.org', 86)]
# oc_8                                                              0.0
# 3gram               ['glo', 'lob', 'obo', 'boc', 'oco', 'com', 'omm']
# char_distribution   defaultdict(<class 'int'>, {'g': 1, 'm': 2, 'b...
# 2gram                ['gl', 'lo', 'ob', 'bo', 'oc', 'co', 'om', 'mm']
# Registrar                                                EuroDNS S.A.
# sld                                                         globocomm
# Name_Server_Count                                                 2.0
# Page_Rank                                                        -1.0
# label                                                               1
# Year                                                           2014.0
# Month                                                             2.0
#
#                                                                483584  \
# Country                                                            NL
# ASN                                                          204915.0
# TTL                                                            3599.0
# IP                                                     145.14.145.115
# Domain                                 b'jokowi12.000webhostapp.com.'
# State                                                         Larnaka
# Country.1                                                          CY
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                                         000WEBHOSTAPP.COM
# Alexa_Rank                                                     3851.0
# subdomain                                                         1.0
# Organization                                              GDPR Masked
# len                                                              22.0
# longest_word                                                        p
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram               ['0', '0', '0', 'w', 'e', 'b', 'h', 'o', 's', ...
# obfuscate_at_sign                                                 0.0
# entropy                                                      3.642649
# Domain_Age                                                     1440.0
# tld                                                               com
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails              ['abuse@hostinger.com', 'gdpr-masking@gdpr-mas...
# numeric_percentage                                          17.857143
# puny_coded                                                        0.0
# typos                       [('twitter.com', 86), ('google.com', 86)]
# oc_8                                                              0.0
# 3gram               ['000', '00w', '0we', 'web', 'ebh', 'bho', 'ho...
# char_distribution   defaultdict(<class 'int'>, {'1': 1, '2': 1, 'w...
# 2gram               ['00', '00', '0w', 'we', 'eb', 'bh', 'ho', 'os...
# Registrar                                               Hostinger UAB
# sld                                                     000webhostapp
# Name_Server_Count                                                 4.0
# Page_Rank                                                        -1.0
# label                                                               1
# Year                                                           2016.0
# Month                                                             5.0
#
#                                                                483585  \
# Country                                                            DE
# ASN                                                           24940.0
# TTL                                                           14399.0
# IP                                                     148.251.70.130
# Domain                                       b'naveenmechanical.com.'
# State                                                             NaN
# Country.1                                                         NaN
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                                                       NaN
# Alexa_Rank                                                        NaN
# subdomain                                                         0.0
# Organization                                                      NaN
# len                                                              17.0
# longest_word                                               mechanical
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram               ['n', 'a', 'v', 'e', 'e', 'n', 'm', 'e', 'c', ...
# obfuscate_at_sign                                                 0.0
# entropy                                                      2.890279
# Domain_Age                                                        NaN
# tld                                                               com
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails                                                            NaN
# numeric_percentage                                                0.0
# puny_coded                                                        0.0
# typos                     [('facebook.com', 86), ('twitter.com', 86)]
# oc_8                                                              0.0
# 3gram               ['nav', 'ave', 'vee', 'een', 'enm', 'nme', 'me...
# char_distribution   defaultdict(<class 'int'>, {'v': 1, 'n': 3, 'e...
# 2gram               ['na', 'av', 've', 'ee', 'en', 'nm', 'me', 'ec...
# Registrar                                                         NaN
# sld                                                  naveenmechanical
# Name_Server_Count                                                 NaN
# Page_Rank                                                         NaN
# label                                                               1
# Year                                                              NaN
# Month                                                             NaN
#
#                                                                483586  \
# Country                                                            NL
# ASN                                                          204915.0
# TTL                                                            3599.0
# IP                                                      145.14.145.85
# Domain                       b'onlinefrepdfviewer.000webhostapp.com.'
# State                                                         Larnaka
# Country.1                                                          CY
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                                         000WEBHOSTAPP.COM
# Alexa_Rank                                                     3851.0
# subdomain                                                         1.0
# Organization                                              GDPR Masked
# len                                                              32.0
# longest_word                                                        p
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram               ['0', '0', '0', 'w', 'e', 'b', 'h', 'o', 's', ...
# obfuscate_at_sign                                                 0.0
# entropy                                                      3.808768
# Domain_Age                                                     1440.0
# tld                                                               com
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails              ['abuse@hostinger.com', 'gdpr-masking@gdpr-mas...
# numeric_percentage                                           7.894737
# puny_coded                                                        0.0
# typos                       [('twitter.com', 86), ('google.com', 86)]
# oc_8                                                              0.0
# 3gram               ['000', '00w', '0we', 'web', 'ebh', 'bho', 'ho...
# char_distribution   defaultdict(<class 'int'>, {'d': 1, 'n': 2, 'r...
# 2gram               ['00', '00', '0w', 'we', 'eb', 'bh', 'ho', 'os...
# Registrar                                               Hostinger UAB
# sld                                                     000webhostapp
# Name_Server_Count                                                 4.0
# Page_Rank                                                        -1.0
# label                                                               1
# Year                                                           2016.0
# Month                                                             5.0
#
#                                                                483587  \
# Country                                                           NaN
# ASN                                                               NaN
# TTL                                                            3599.0
# IP                                                                NaN
# Domain                       b'onlinefrepdfviewer.000webhostapp.com.'
# State                                                         Larnaka
# Country.1                                                          CY
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                                         000WEBHOSTAPP.COM
# Alexa_Rank                                                     3851.0
# subdomain                                                         1.0
# Organization                                              GDPR Masked
# len                                                              32.0
# longest_word                                                        p
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram               ['0', '0', '0', 'w', 'e', 'b', 'h', 'o', 's', ...
# obfuscate_at_sign                                                 0.0
# entropy                                                      3.808768
# Domain_Age                                                     1440.0
# tld                                                               com
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails              ['abuse@hostinger.com', 'gdpr-masking@gdpr-mas...
# numeric_percentage                                           7.894737
# puny_coded                                                        0.0
# typos                       [('twitter.com', 86), ('google.com', 86)]
# oc_8                                                              0.0
# 3gram               ['000', '00w', '0we', 'web', 'ebh', 'bho', 'ho...
# char_distribution   defaultdict(<class 'int'>, {'d': 1, 'n': 2, 'r...
# 2gram               ['00', '00', '0w', 'we', 'eb', 'bh', 'ho', 'os...
# Registrar                                               Hostinger UAB
# sld                                                     000webhostapp
# Name_Server_Count                                                 4.0
# Page_Rank                                                        -1.0
# label                                                               1
# Year                                                           2016.0
# Month                                                             5.0
#
#                                                                483588  \
# Country                                                            DE
# ASN                                                            8767.0
# TTL                                                            1799.0
# IP                                                      62.245.182.18
# Domain                                       b'stefanie-bolemant.de.'
# State                                                             NaN
# Country.1                                                         NaN
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                                      stefanie-bolemant.de
# Alexa_Rank                                                       -1.0
# subdomain                                                         0.0
# Organization                                                      NaN
# len                                                              18.0
# longest_word                                                 stefanie
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram               ['s', 't', 'e', 'f', 'a', 'n', 'i', 'e', '-', ...
# obfuscate_at_sign                                                 0.0
# entropy                                                      3.340769
# Domain_Age                                                        NaN
# tld                                                                de
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails                                                            NaN
# numeric_percentage                                                0.0
# puny_coded                                                        0.0
# typos                       [('google.de', 86), ('e-recht24.de', 86)]
# oc_8                                                              0.0
# 3gram               ['ste', 'tef', 'efa', 'fan', 'ani', 'nie', 'ie...
# char_distribution   defaultdict(<class 'int'>, {'-': 1, 'n': 2, 'm...
# 2gram               ['st', 'te', 'ef', 'fa', 'an', 'ni', 'ie', 'e-...
# Registrar                                                         NaN
# sld                                                 stefanie-bolemant
# Name_Server_Count                                                 0.0
# Page_Rank                                                        -1.0
# label                                                               1
# Year                                                              NaN
# Month                                                             NaN
#
#                                                                483589
# Country                                                            DE
# ASN                                                            8767.0
# TTL                                                            1799.0
# IP                                                      62.245.182.48
# Domain                                             b'web.asamnet.de.'
# State                                                             NaN
# Country.1                                                         NaN
# hex_32                                                            0.0
# hex_8                                                             0.0
# Domain_Name                                                asamnet.de
# Alexa_Rank                                                  5004230.0
# subdomain                                                         1.0
# Organization                                                      NaN
# len                                                              11.0
# longest_word                                                     mnet
# oc_32                                                             0.0
# shortened                                                        -1.0
# 1gram                             ['a', 's', 'a', 'm', 'n', 'e', 't']
# obfuscate_at_sign                                                 0.0
# entropy                                                      2.781301
# Domain_Age                                                        NaN
# tld                                                                de
# dec_8                                                             0.0
# dec_32                                                            0.0
# Emails                                                            NaN
# numeric_percentage                                                0.0
# puny_coded                                                        0.0
# typos                [('gesetze-im-internet.de', 86), ('web.de', 86)]
# oc_8                                                              0.0
# 3gram                             ['asa', 'sam', 'amn', 'mne', 'net']
# char_distribution   defaultdict(<class 'int'>, {'t': 1, 'n': 1, 'a...
# 2gram                            ['as', 'sa', 'am', 'mn', 'ne', 'et']
# Registrar                                                         NaN
# sld                                                           asamnet
# Name_Server_Count                                                 0.0
# Page_Rank                                                        -1.0
# label                                                               1
# Year                                                              NaN
# Month                                                             NaN
#
# [39 rows x 483590 columns]

# %% [markdown]
# Check for infinite values

# %%
df_concat.describe()
# Out:
#                  ASN            TTL         hex_32     hex_8    Alexa_Rank  \
# count  378035.000000  483566.000000  483220.000000  483563.0  4.348310e+05
# mean    36134.638266    4622.951086       0.000010       0.0  8.070208e+05
# std     53119.391007    6655.870855       0.003217       0.0  1.908852e+06
# min         3.000000       0.000000       0.000000       0.0 -1.000000e+00
# 25%     13335.000000     299.000000       0.000000       0.0 -1.000000e+00
# 50%     19551.000000     899.000000       0.000000       0.0  7.888500e+04
# 75%     40034.000000    3888.750000       0.000000       0.0  5.114350e+05
# max    398246.000000  397224.000000       1.000000       0.0  1.091875e+07
#
#           subdomain            len     oc_32      shortened  \
# count  4.834610e+05  452572.000000  452816.0  482102.000000
# mean   5.376280e+02      12.057628       inf      -0.935984
# std    4.951540e+04       4.978037       NaN       0.244934
# min   -1.000000e+00      -1.000000      -1.0      -1.000000
# 25%    0.000000e+00       8.000000       0.0      -1.000000
# 50%    0.000000e+00      11.000000       0.0      -1.000000
# 75%    1.000000e+00      15.000000       0.0      -1.000000
# max    1.069806e+07     142.000000       inf       3.108098
#
#        obfuscate_at_sign  ...     dec_8         dec_32  numeric_percentage  \
# count      452740.000000  ...  452701.0  483102.000000       451505.000000
# mean            0.001065  ...       0.0       0.002511            0.879707
# std             0.054596  ...       0.0       0.050046            4.246263
# min             0.000000  ...       0.0       0.000000            0.000000
# 25%             0.000000  ...       0.0       0.000000            0.000000
# 50%             0.000000  ...       0.0       0.000000            0.000000
# 75%             0.000000  ...       0.0       0.000000            0.000000
# max             3.581015  ...       0.0       1.000000           72.727273
#
#           puny_coded      oc_8  Name_Server_Count      Page_Rank  \
# count  483099.000000  451014.0       3.360820e+05  434720.000000
# mean        0.053130       0.0       1.487732e+53      -0.098797
# std         0.937139       0.0       8.624767e+55       1.883598
# min         0.000000       0.0      -1.000000e+00      -1.000000
# 25%         0.000000       0.0       2.000000e+00      -1.000000
# 50%         0.000000       0.0       2.000000e+00      -1.000000
# 75%         0.000000       0.0       4.000000e+00      -1.000000
# max        62.500000       0.0       5.000000e+58      42.000000
#
#                label           Year          Month
# count  483590.000000  362665.000000  362665.000000
# mean        0.010292    2006.865876       6.334253
# std         0.100925       7.854269       3.447802
# min         0.000000    1985.000000       1.000000
# 25%         0.000000    2000.000000       3.000000
# 50%         0.000000    2006.000000       6.000000
# 75%         0.000000    2014.000000       9.000000
# max         1.000000    2020.000000      12.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# Remove inf values

# %%
df_concat = df_concat.replace([np.inf, -np.inf], np.nan)

# %%
df_concat.isin([np.inf, -np.inf]).any().any()
# Out:
# False

# %%
# Save the DataFrame to a pickle file
df_concat.to_pickle('Data/processed_data.pkl')

# %%
# Calculate the percentage of NaN values in each column
unique_percentage = (df_concat[categorical_columns].nunique())

# Create a bar plot
plt.figure(figsize=(10, 6))
unique_percentage.plot(kind='bar', color='skyblue')
plt.title('Number of Unique Values in Categorical Columns')
plt.xlabel('Columns')
plt.ylabel('Qty.')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.show()
